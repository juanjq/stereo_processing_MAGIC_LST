# %%
import glob
import itertools
from pathlib import Path

import numpy as np
import pandas as pd
from astropy import units as u
from astropy.coordinates import SkyCoord
from gammapy.stats import WStatCountsStatistic
from magicctapipe.io import get_dl2_mean, get_stereo_events
from magicctapipe.utils import calculate_off_coordinates
from matplotlib import pyplot as plt

# %%
# Display all the columns of a pandas data frame
pd.set_option("display.max_columns", None)

# Customize the pyplot figure
plt.rcParams.update(
    {"figure.figsize": (12, 9), "font.size": 15, "grid.linestyle": "dotted"}
)

# Get the pyplot default color cycle
colors = ['darkblue', 'deeppink', 'c', 'darkorange'] #plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %% [markdown]
# # Load input DL2 data files

# %%
# ================
# === Settings ===
# ================

input_file_mask = (
    "/fefs/aswg/workspace/juan.jimenez/data/STEREO_DL2/*")

quality_cuts = f"(disp_diff_mean < {np.sqrt(0.05)})"

# ============
# === Main ===
# ============

print(f"Input file mask: {input_file_mask}")

# Find the input files
input_files = glob.glob(input_file_mask)
input_files.sort()

print("\nThe following files are found:")

data_list = []

for input_file in input_files:

    print(Path(input_file).name)

    # Load the input file
    df_events = pd.read_hdf(input_file, key="events/parameters")
    data_list.append(df_events)

event_data = pd.concat(data_list)
event_data.set_index(["obs_id", "event_id", "tel_id"], inplace=True)
event_data.sort_index(inplace=True)

# Apply the quality cuts
print(f"\nQuality cuts: {quality_cuts}")
event_data = get_stereo_events(event_data, quality_cuts)

# Exclude the MAGIC-stereo combination events, since they are
# poorly reconstructred with the current analysis scheme
print("Excluding the MAGIC-stereo combination events...")
event_data.query("combo_type != 0", inplace=True)

# Show the data frame
event_data.head()
# Out:
# Input file mask: /fefs/aswg/workspace/juan.jimenez/data/STEREO_DL2/*
#
# The following files are found:
# dl2_LST-1_MAGIC.Run02923.h5
# dl2_LST-1_MAGIC.Run02960.h5
# dl2_LST-1_MAGIC.Run03265.h5
# dl2_LST-1_MAGIC.Run03266.h5
# dl2_LST-1_MAGIC.Run03268.h5
# dl2_LST-1_MAGIC.Run03631.h5
# dl2_LST-1_MAGIC.Run03632.h5
# dl2_LST-1_MAGIC.Run03633.h5
# dl2_LST-1_MAGIC.Run03634.h5
# dl2_LST-1_MAGIC.Run03635.h5
# dl2_LST-1_MAGIC.Run03636.h5
# dl2_LST-1_MAGIC.Run03955.h5
# dl2_LST-1_MAGIC.Run03956.h5
# dl2_LST-1_MAGIC.Run07198.h5
# dl2_LST-1_MAGIC.Run07201.h5
# dl2_LST-1_MAGIC.Run07227.h5
# dl2_LST-1_MAGIC.Run07230.h5
# dl2_LST-1_MAGIC.Run07231.h5
# dl2_LST-1_MAGIC.Run07232.h5
# dl2_LST-1_MAGIC.Run07233.h5
# dl2_LST-1_MAGIC.Run07234.h5
# dl2_LST-1_MAGIC.Run07235.h5
# dl2_LST-1_MAGIC.Run07236.h5
# dl2_LST-1_MAGIC.Run07237.h5
# dl2_LST-1_MAGIC.Run07238.h5
#
# Quality cuts: (disp_diff_mean < 0.22360679774997896)
# In total 279428 stereo events are found:
#     M1_M2 (type 0): 55663 events (19.9%)
#     LST1_M1 (type 1): 19626 events (7.0%)
#     LST1_M2 (type 2): 54977 events (19.7%)
#     LST1_M1_M2 (type 3): 149162 events (53.4%)
# Excluding the MAGIC-stereo combination events...
#                         obs_id_magic  event_id_magic  obs_id_lst  \
# obs_id event_id tel_id
# 2923   2054693  1            5093174            2130      2923.0
#                 2            5093174            2130      2923.0
#                 3            5093174            2130      2923.0
#        2054766  1            5093174            2132      2923.0
#                 2            5093174            2132      2923.0
#
#                         event_id_lst    intensity         x         y  \
# obs_id event_id tel_id
# 2923   2054693  1          2054693.0   506.865746 -0.656543  0.090178
#                 2          2054693.0   309.348958 -0.267904  0.084833
#                 3          2054693.0   268.299479 -0.314013  0.010559
#        2054766  1          2054766.0  1539.117331  0.159153 -0.199730
#                 2          2054766.0   682.101041  0.219247 -0.123636
#
#                                r         phi    length  length_uncertainty  \
# obs_id event_id tel_id
# 2923   2054693  1       0.662707  172.179240  0.087614            0.005056
#                 2       0.281014  162.429424  0.044108            0.001455
#                 3       0.314191  178.074182  0.054217            0.002036
#        2054766  1       0.255385  -51.450648  0.095864            0.003028
#                 2       0.251705  -29.419061  0.100258            0.002468
#
#                            width  width_uncertainty        psi  skewness  \
# obs_id event_id tel_id
# 2923   2054693  1       0.038988           0.002505  48.813059 -0.369646
#                 2       0.027682           0.001071  80.681458  0.067720
#                 3       0.025034           0.000991  71.841862 -0.396296
#        2054766  1       0.041476           0.001832  39.938156 -0.450708
#                 2       0.039357           0.001128  65.294646 -0.720628
#
#                         kurtosis     slope  intercept  intensity_width_1  \
# obs_id event_id tel_id
# 2923   2054693  1       2.612286 -3.738599  19.435415                0.0
#                 2       2.347090  4.956926  14.463646                0.0
#                 3       2.513928 -2.827833  14.339549                0.0
#        2054766  1       2.467139 -7.488149  19.800128                0.0
#                 2       2.653032  7.173953  15.740397                0.0
#
#                         intensity_width_2  pixels_width_1  pixels_width_2  \
# obs_id event_id tel_id
# 2923   2054693  1                     0.0             0.0             0.0
#                 2                     0.0             0.0             0.0
#                 3                     0.0             0.0             0.0
#        2054766  1                     0.0             0.0             0.0
#                 2                     0.0             0.0             0.0
#
#                         n_pixels  n_islands  pointing_alt  pointing_az  \
# obs_id event_id tel_id
# 2923   2054693  1             27          1      0.784340     1.508031
#                 2             27          1      0.784257     1.508029
#                 3             26          1      0.784235     1.508001
#        2054766  1             42          1      0.784340     1.508031
#                 2             61          1      0.784258     1.508029
#
#                            timestamp  time_diff  multiplicity  combo_type  \
# obs_id event_id tel_id
# 2923   2054693  1       1.605743e+09   0.000023             3           3
#                 2       1.605743e+09   0.002819             3           3
#                 3       1.605743e+09   2.727715             3           3
#        2054766  1       1.605743e+09   0.000020             3           3
#                 2       1.605743e+09   0.002003             3           3
#
#                               alt  alt_uncert         az  az_uncert  \
# obs_id event_id tel_id
# 2923   2054693  1       44.200646    0.086457  87.620957   0.086457
#                 2       44.200646    0.086457  87.620957   0.086457
#                 3       44.200646    0.086457  87.620957   0.086457
#        2054766  1       45.713880    0.185925  86.308094   0.185925
#                 2       45.713880    0.185925  86.308094   0.185925
#
#                             core_x     core_y      impact         h_max  \
# obs_id event_id tel_id
# 2923   2054693  1       136.335103 -79.723178  178.834034  12103.976098
#                 2       136.335103 -79.723178   97.262421  12103.976098
#                 3       136.335103 -79.723178  172.228251  12103.976098
#        2054766  1        68.437147 -50.467934  117.100531  15205.132850
#                 2        68.437147 -50.467934   30.898989  15205.132850
#
#                         reco_energy  reco_energy_var  reco_disp  \
# obs_id event_id tel_id
# 2923   2054693  1          0.317139         0.029565   0.915416
#                 2          0.427406         0.011377   0.572556
#                 3          0.272372         0.017186   0.767506
#        2054766  1          1.160295         0.009623   0.818525
#                 2          0.966992         0.025346   0.597132
#
#                         reco_disp_var   reco_alt    reco_az  disp_diff_sum  \
# obs_id event_id tel_id
# 2923   2054693  1            0.004338  44.192237  87.622001       0.227590
#                 2            0.008255  44.178599  87.563649       0.227590
#                 3            0.007985  44.179724  87.465316       0.227590
#        2054766  1            0.033666  45.892510  86.571648       0.380246
#                 2            0.049796  45.873738  86.624261       0.380246
#
#                         disp_diff_mean  gammaness  gammaness_var
# obs_id event_id tel_id
# 2923   2054693  1             0.075863   0.787881       0.167125
#                 2             0.075863   0.763333       0.180656
#                 3             0.075863   0.894167       0.094633
#        2054766  1             0.126749   0.905000       0.085975
#                 2             0.126749   0.023333       0.022789

# %%
event_data.head()
# Out:
#                         obs_id_magic  event_id_magic  obs_id_lst  \
# obs_id event_id tel_id
# 2923   2054288  1            5093174            2122      2923.0
#                 2            5093174            2122      2923.0
#        2054414  1            5093174            2126      2923.0
#                 2            5093174            2126      2923.0
#        2054693  1            5093174            2130      2923.0
#
#                         event_id_lst   intensity         x         y  \
# obs_id event_id tel_id
# 2923   2054288  1          2054288.0  341.879600 -0.449762  0.488456
#                 2          2054288.0  108.671875  0.027797  0.335385
#        2054414  1          2054414.0   79.065451  0.055524 -0.122445
#                 2          2054414.0  176.444987  0.319373  0.086378
#        2054693  1          2054693.0  506.865746 -0.656543  0.090178
#
#                                r         phi    length  length_uncertainty  \
# obs_id event_id tel_id
# 2923   2054288  1       0.663985  132.638326  0.172365            0.011208
#                 2       0.336535   85.262067  0.085343            0.002247
#        2054414  1       0.134446  -65.607500  0.047799            0.004400
#                 2       0.330847   15.134165  0.092057            0.002665
#        2054693  1       0.662707  172.179240  0.087614            0.005056
#
#                            width  width_uncertainty        psi  skewness  \
# obs_id event_id tel_id
# 2923   2054288  1       0.098873           0.005420  11.063750  0.665832
#                 2       0.017875           0.001107 -25.261473 -0.350821
#        2054414  1       0.023214           0.002552  10.861540 -0.163052
#                 2       0.019301           0.000749  53.087812 -0.118283
#        2054693  1       0.038988           0.002505  48.813059 -0.369646
#
#                         kurtosis      slope  intercept  intensity_width_1  \
# obs_id event_id tel_id
# 2923   2054288  1       2.380931  -5.910495  18.244737                0.0
#                 2       1.301270 -21.086121  14.992932                0.0
#        2054414  1       1.640131 -11.942434  12.055380                0.0
#                 2       1.591619   3.427512  11.703914                0.0
#        2054693  1       2.612286  -3.738599  19.435415                0.0
#
#                         intensity_width_2  pixels_width_1  pixels_width_2  \
# obs_id event_id tel_id
# 2923   2054288  1                0.000000             0.0        0.000000
#                 2                0.000000             0.0        0.000000
#        2054414  1                0.000000             0.0        0.000000
#                 2                0.026655             0.0        0.000962
#        2054693  1                0.000000             0.0        0.000000
#
#                         n_pixels  n_islands  pointing_alt  pointing_az  \
# obs_id event_id tel_id
# 2923   2054288  1             25          3      0.784338     1.508030
#                 2             13          2      0.784255     1.508028
#        2054414  1              7          1      0.784338     1.508031
#                 2             19          2      0.784256     1.508028
#        2054693  1             27          1      0.784340     1.508031
#
#                            timestamp  time_diff  multiplicity  combo_type  \
# obs_id event_id tel_id
# 2923   2054288  1       1.605743e+09   0.000050             2           1
#                 2       1.605743e+09   2.692617             2           1
#        2054414  1       1.605743e+09   0.000080             2           1
#                 2       1.605743e+09   0.002745             2           1
#        2054693  1       1.605743e+09   0.000023             3           3
#
#                               alt  alt_uncert         az  az_uncert  \
# obs_id event_id tel_id
# 2923   2054288  1       44.799705    0.000000  88.030824   0.000000
#                 2       44.799705    0.000000  88.030824   0.000000
#        2054414  1       45.630011    0.000000  86.203905   0.000000
#                 2       45.630011    0.000000  86.203905   0.000000
#        2054693  1       44.200646    0.086457  87.620957   0.086457
#
#                             core_x      core_y      impact         h_max  \
# obs_id event_id tel_id
# 2923   2054288  1        28.694622 -103.785913  132.419066   5878.375619
#                 2        28.694622 -103.785913   30.555693   5878.375619
#        2054414  1        15.722143  -41.348783   87.637208   6016.734631
#                 2        15.722143  -41.348783   27.849021   6016.734631
#        2054693  1       136.335103  -79.723178  178.834034  12103.976098
#
#                         reco_energy  reco_energy_var  reco_disp  \
# obs_id event_id tel_id
# 2923   2054288  1          0.400253         0.339353   1.296976
#                 2          0.713004         0.073478   1.055499
#        2054414  1          0.199976         0.070969   1.709209
#                 2          0.211255         0.166419   0.816520
#        2054693  1          0.317139         0.029565   0.915416
#
#                         reco_disp_var   reco_alt    reco_az  disp_diff_sum  \
# obs_id event_id tel_id
# 2923   2054288  1            0.244008  45.278116  88.178006       0.939862
#                 2            0.169564  45.973266  87.273500       0.939862
#        2054414  1            0.450509  46.731422  86.508243       0.904582
#                 2            0.060054  46.421973  87.744845       0.904582
#        2054693  1            0.004338  44.192237  87.622001       0.227590
#
#                         disp_diff_mean  gammaness  gammaness_var
# obs_id event_id tel_id
# 2923   2054288  1             0.939862   0.005000       0.004975
#                 2             0.939862   0.061667       0.057864
#        2054414  1             0.904582   0.093833       0.085029
#                 2             0.904582   0.038810       0.037303
#        2054693  1             0.075863   0.787881       0.167125

# %%
# Get mean DL2 parameters
print("Calculating mean DL2 parameters...")
event_data_mean = get_dl2_mean(event_data)

# Show the data frame
event_data_mean.head()
# Out:
# Calculating mean DL2 parameters...
#                  combo_type  multiplicity     timestamp  pointing_alt  \
# obs_id event_id
# 2923   2054693            3             3  1.605743e+09      0.784277
#        2054766            3             3  1.605743e+09      0.784278
#        2055329            3             3  1.605743e+09      0.784281
#        2057236            3             3  1.605743e+09      0.784291
#        2058508            1             2  1.605743e+09      0.784319
#
#                  pointing_az  reco_energy   reco_alt    reco_az  gammaness  \
# obs_id event_id
# 2923   2054693      1.508020     0.332979  44.183538  87.550317   0.815127
#        2054766      1.508020     1.043925  45.828519  86.617489   0.486476
#        2055329      1.508022     2.009260  44.053245  86.437994   0.096417
#        2057236      1.508026     0.543667  45.512389  84.280677   0.538226
#        2058508      1.508039     0.328179  46.324765  86.237417   0.856770
#
#                  pointing_ra  pointing_dec    reco_ra   reco_dec
# obs_id event_id
# 2923   2054693     83.966938     22.246320  84.438578  21.225500
#        2054766     83.966939     22.246320  83.000934  22.391517
#        2055329     83.966941     22.246325  84.858546  21.934265
#        2057236     83.966948     22.246340  83.878095  23.846509
#        2058508     83.965582     22.246383  82.582942  22.798855

# %%
# Calculate the observation time
time_diffs = np.diff(event_data_mean["timestamp"])
obs_time = time_diffs[time_diffs < 1].sum() * u.s

print(f"Observation time: {obs_time.to('min'):.1f}")
# Out:
# Observation time: 313.4 min

# %% [markdown]
# # Calculate the angular distances from ON and OFF regions

# %%
# ================
# === Settings ===
# ================

source_name = "Crab"
n_regions_off = 3

# ============
# === Main ===
# ============

on_coord = SkyCoord.from_name(source_name, frame="icrs")

print(f"ON coordinate ({source_name}):")
print(on_coord)

xlim = on_coord.ra.to_value("deg") + np.array([2, -2])
ylim = on_coord.dec.to_value("deg") + np.array([-2, 2])

print(f"\nNumber of OFF regions: {n_regions_off}")

# Loop over every observation ID
obs_ids = np.unique(event_data_mean.index.get_level_values("obs_id"))

for obs_id in obs_ids:

    print(f"\nObservation ID: {obs_id}")
    df_events = event_data_mean.query(f"obs_id == {obs_id}")

    event_coords = SkyCoord(
        u.Quantity(df_events["reco_ra"], unit="deg"),
        u.Quantity(df_events["reco_dec"], unit="deg"),
        frame="icrs",
    )

    pnt_ra_mean = df_events["pointing_ra"].mean() * u.deg
    pnt_dec_mean = df_events["pointing_dec"].mean() * u.deg

    # Create a figure
    plt.figure(figsize=(8, 8))
    plt.title(f"Observation ID: {obs_id}")
    plt.xlabel("RA [deg]")
    plt.ylabel("Dec [deg]")
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.grid()

    # Plot the ON coordinate
    plt.scatter(
        on_coord.ra.to("deg"), on_coord.dec.to("deg"), label="ON", marker="*", s=400, color=colors[0]
    )

    # Plot the pointing direction
    plt.scatter(
        pnt_ra_mean, pnt_dec_mean, label="Pointing", marker="o", s=200, color="grey"
    )

    # Calculate the angular distances from the ON region
    theta_on = on_coord.separation(event_coords)
    theta2_on = theta_on.to_value("deg") ** 2

    event_data_mean.loc[(obs_id, slice(None)), "theta2_on"] = theta2_on

    # Calculate the OFF coordinates
    off_coords = calculate_off_coordinates(
        pointing_ra=pnt_ra_mean,
        pointing_dec=pnt_dec_mean,
        on_coord_ra=on_coord.ra,
        on_coord_dec=on_coord.dec,
        n_regions=n_regions_off,
    )

    # Loop over every OFF coordinate
    print("\nOFF coordinates:")

    for i_off, off_coord in off_coords.items():

        print(off_coord)

        # Calculate the angular distance from the OFF coordinate
        theta_off = off_coord.separation(event_coords)
        theta2_off = theta_off.to_value("deg") ** 2

        event_data_mean.loc[(obs_id, slice(None)), f"theta2_off{i_off}"] = theta2_off

        # Plot the OFF coordinate
        plt.scatter(
            off_coord.ra.to("deg"),
            off_coord.dec.to("deg"),
            label=f"OFF{i_off}",
            marker="x",
            s=200,
            color=colors[i_off],
        )

    plt.legend()
    plt.show()
# Out:
# ON coordinate (Crab):
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.6333, 22.0133)>
#
# Number of OFF regions: 3
#
# Observation ID: 2923
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.30324688, 22.47943415)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.71525145, 22.555954)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.21961941, 21.93639518)>
# Observation ID: 2960
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34850945, 22.480343)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.73728025, 22.57733535)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24273616, 21.91592158)>
# Observation ID: 3265
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.29869224, 22.48109633)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.71208245, 22.55467489)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.21823918, 21.93933366)>
# Observation ID: 3266
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.89391763, 21.56142286)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.50561677, 21.4436301)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.01985722, 22.13073321)>
# Observation ID: 3268
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.90120371, 21.56364379)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.50808714, 21.44813171)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.02469846, 22.12845609)>
# Observation ID: 3631
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.9338546, 21.55946179)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.52672922, 21.46120144)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.03876864, 22.11119806)>
# Observation ID: 3632
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34307715, 22.47764962)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.73604, 22.5734838)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.23856813, 21.91708417)>
# Observation ID: 3633
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.93786639, 21.55983834)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.52854259, 21.46325475)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.0409779, 22.10952194)>
# Observation ID: 3634
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34729357, 22.47859078)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.73762685, 22.5759016)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24118353, 21.91560601)>
# Observation ID: 3635
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.94168711, 21.55957197)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.53060445, 21.46489622)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.04274483, 22.10761371)>
# Observation ID: 3636
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.35290197, 22.47747686)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.74102228, 22.5779409)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24338682, 21.91245469)>
# Observation ID: 3955
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.93366121, 21.56270864)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.52489234, 21.46274304)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.04042339, 22.11290843)>
# Observation ID: 3956
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34463175, 22.48031252)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.73536742, 22.57552716)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24078115, 21.9176993)>
# Observation ID: 7198
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34570828, 22.4840686)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.73386325, 22.57789314)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24334461, 21.91908311)>
# Observation ID: 7201
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.95221258, 21.56379874)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.53362623, 21.47191057)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.05028824, 22.10483286)>
# Observation ID: 7227
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.34041127, 22.48717489)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.72954079, 22.57698891)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24237155, 21.92308833)>
# Observation ID: 7230
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.93735147, 21.56606283)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.52494862, 21.46614305)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.04407808, 22.11286789)>
# Observation ID: 7231
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.35085517, 22.48470063)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.7360808, 22.58058734)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24625845, 21.91701992)>
# Observation ID: 7232
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.9443307, 21.56520178)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.52891554, 21.46895325)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.04710358, 22.10919536)>
# Observation ID: 7233
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.35884092, 22.4833633)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.74078028, 22.58361471)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.24952974, 21.91265754)>
# Observation ID: 7234
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.95210177, 21.56417871)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.53336695, 21.47204999)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.05043779, 22.10507401)>
# Observation ID: 7235
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.3644727, 22.48575395)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.74228378, 22.58740773)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.25363428, 21.91125121)>
# Observation ID: 7236
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.95736898, 21.56882301)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.53352357, 21.4768307)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.0555769, 22.10494488)>
# Observation ID: 7237
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (82.95865273, 21.56877165)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.53419585, 21.47740137)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.05619116, 22.10432278)>
# Observation ID: 7238
#
# OFF coordinates:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.37198806, 22.48725042)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (83.74520989, 22.59162689)>
# <SkyCoord (ICRS): (ra, dec) in deg
#     (84.2581984, 21.90852604)>

# %% [markdown]
# # Get an event list

# %%
# ================
# === Settings ===
# ================

combo_types = [3]
cut_value_gh = 0.8

# ============
# === Main ===
# ============

print(f"Combination types: {combo_types}")
print(f"Global gammaness cut: {cut_value_gh}")

# Get the event list
event_list = event_data_mean.query(
    f"(combo_type == {combo_types}) & (gammaness > {cut_value_gh})"
).copy()

print(f"\nNumber of events: {len(event_list)}")

# Show the event list
event_list.head()
# Out:
# Combination types: [3]
# Global gammaness cut: 0.8
#
# Number of events: 39809
#                  combo_type  multiplicity     timestamp  pointing_alt  \
# obs_id event_id
# 2923   2054693            3             3  1.605743e+09      0.784277
#        2062474            3             3  1.605743e+09      0.784321
#        2063703            3             3  1.605743e+09      0.784328
#        2066692            3             3  1.605743e+09      0.784345
#        2073564            3             3  1.605743e+09      0.784383
#
#                  pointing_az  reco_energy   reco_alt    reco_az  gammaness  \
# obs_id event_id
# 2923   2054693      1.508020     0.332979  44.183538  87.550317   0.815127
#        2062474      1.508040     0.211112  45.749724  86.624973   0.921722
#        2063703      1.508043     0.285001  46.309994  86.103019   0.976944
#        2066692      1.508051     0.415360  46.415574  87.339700   0.834960
#        2073564      1.508068     0.372542  46.038362  85.335943   0.854468
#
#                  pointing_ra  pointing_dec    reco_ra   reco_dec  theta2_on  \
# obs_id event_id
# 2923   2054693     83.966938     22.246320  84.438578  21.225500   1.181059
#        2062474     83.966968     22.246383  83.082681  22.361304   0.381051
#        2063703     83.966973     22.246394  82.631646  22.882417   1.612360
#        2066692     83.966985     22.246418  82.230576  22.106880   1.698826
#        2073564     83.966997     22.246457  83.094439  23.303752   1.912528
#
#                  theta2_off1  theta2_off2  theta2_off3
# obs_id event_id
# 2923   2054693      1.588127     2.220549     0.546828
#        2062474      1.287018     0.379638     1.289431
#        2063703      2.541138     1.105624     3.050049
#        2066692      3.816481     2.087665     3.429082
#        2073564      1.919578     0.886101     2.948328

# %% [markdown]
# # Check the count map

# %%
plt.figure()
plt.title(f"gammaness > {cut_value_gh}, combo_type = {combo_types}")
plt.xlabel("RA [deg]")
plt.ylabel("Dec [deg]")
plt.xlim(xlim)
plt.ylim(ylim)

# Plot the count map
plt.hist2d(
    event_list["reco_ra"],
    event_list["reco_dec"],
    bins=[np.linspace(xlim[1], xlim[0], 101), np.linspace(ylim[0], ylim[1], 101)],
    cmap='Blues_r'
)

plt.colorbar(label="Number of events")
plt.axis(xlim.tolist() + ylim.tolist())
plt.grid()

# Plot the ON coordinate
plt.scatter(
    on_coord.ra.to("deg"),
    on_coord.dec.to("deg"),
    marker="x",
    s=100,
    color="red",
    label="ON",
)

plt.legend()
plt.show()

# %% [markdown]
# # Check the theta2 distributions

# %%
# ================
# === Settings ===
# ================

theta2_bins = np.linspace(0, 0.4, 120)  # unit: [deg2]
cut_value_theta2 = 0.04  # unit: [deg2]

# ============
# === Main ===
# ============

theta2_bins_center = (theta2_bins[:-1] + theta2_bins[1:]) / 2

theta2_bins_width = [
    theta2_bins_center - theta2_bins[:-1],
    theta2_bins[1:] - theta2_bins_center,
]

plt.figure(figsize=(12,7))
plt.title(f"gammaness > {cut_value_gh}, combo_type = {combo_types}")
plt.xlabel("Theta2 [deg$^2$]")
plt.ylabel("Number of events")
plt.grid()

# Plot the theta2 distribution from the ON coordinate
hist_on = plt.hist(
    event_list["theta2_on"], bins=theta2_bins, histtype="stepfilled", linewidth=2,
    alpha=1,color='lightgray')[0]
hist_on = plt.hist(
    event_list["theta2_on"], bins=theta2_bins, histtype="step", linewidth=1.4,
    alpha=1,color='k')[0]

plt.errorbar(
    x=theta2_bins_center,
    y=hist_on,
    xerr=theta2_bins_width,
    yerr=np.sqrt(hist_on),
    fmt=".",
    markersize=0,
    label="ON",
    color='k', zorder=10
)

# Plot the theta2 distrubutions from the OFF coordinates
for i_off in range(n_regions_off):

    hist_off, _ = np.histogram(event_list[f"theta2_off{i_off+1}"], bins=theta2_bins)

    plt.errorbar(
        x=theta2_bins_center,
        y=hist_off,
        xerr=theta2_bins_width,
        yerr=np.sqrt(hist_off),
        fmt="o",
        markersize=1,
        label=f"OFF{i_off+1}",
        color=colors[i_off+1]
    )

# Plot the theta2 cut
print(f"Global theta2 cut: {cut_value_theta2} [deg2]")

plt.axvline(cut_value_theta2, linestyle="--", color="black", label=f"Theta2 cut",)

plt.legend(loc="upper right")

# Calculate the numbers ON, OFF and excess events
n_on = len(event_list.query(f"theta2_on < {cut_value_theta2}"))
print(f"\nNon: {n_on}\n")

n_off_total = 0

for i_off in range(n_regions_off):

    n_off = len(event_list.query(f"theta2_off{i_off+1} < {cut_value_theta2}"))
    print(f"Noff{i_off+1}: {n_off}")

    n_off_total += n_off

print(f"--> Total Noff: {n_off_total}")

alpha = 1 / n_regions_off
n_off_scaled = n_off_total * alpha

print(f"\nalpha = {alpha:.3f}")
print(f"--> Scaled Noff: {n_off_scaled:.0f}")

n_excess = n_on - n_off_scaled
excess_rate = n_excess / obs_time.to_value("min")

print(f"\nNexcess: {n_excess:.0f}")
print(f"Observation time: {obs_time.to('min'):.1f}")
print(f"--> Excess rate: {excess_rate:.1f} [1/min]")

# Calculate the Li&Ma significance
stat = WStatCountsStatistic(n_on, n_off_total, alpha=alpha)
significance = stat.sqrt_ts

print(f"\nLi&Ma significance: {significance:.1f} sigma")
# Out:
# Global theta2 cut: 0.04 [deg2]
#
# Non: 5607
#
# Noff1: 892
# Noff2: 998
# Noff3: 991
# --> Total Noff: 2881
#
# alpha = 0.333
# --> Scaled Noff: 960
#
# Nexcess: 4647
# Observation time: 313.4 min
# --> Excess rate: 14.8 [1/min]
#
# Li&Ma significance: 79.5 sigma

# %%
# ================
# === Settings ===
# ================

energy_bins = np.logspace(-1, 1, 11)[:-4]

# ============
# === Main ===
# ============

n_columns = 3
n_rows = int(np.ceil(len(energy_bins[:-1]) / n_columns))

grid = (n_rows, n_columns)
locs = list(itertools.product(range(n_rows), range(n_columns)))

plt.figure(figsize=(20, n_rows * 8))

# Loop over every energy bin
for i_bin, (eng_lo, eng_hi) in enumerate(zip(energy_bins[:-1], energy_bins[1:])):

    plt.subplot2grid(grid, locs[i_bin])
    plt.title(f"{eng_lo:.3f} < energy < {eng_hi:.3f} [TeV]")
    plt.xlabel("Theta2 [deg$^2$]")
    plt.ylabel("Number of events")
    plt.grid()

    # Apply the energy cut
    df_events = event_list.query(
        f"(reco_energy > {eng_lo}) & (reco_energy < {eng_hi})"
    ).copy()

    if len(df_events) > 0:

        # Plot the theta2 distribution from the ON coordinate
        hist_on = plt.hist(
            df_events["theta2_on"],
            bins=theta2_bins,
            histtype="bar",
            linewidth=2,
            alpha=0.5,
        )[0]

        plt.errorbar(
            x=theta2_bins_center,
            y=hist_on,
            xerr=theta2_bins_width,
            yerr=np.sqrt(hist_on),
            fmt="o",
            markersize=5,
            label="ON",
            color=colors[0],
        )

        # Plot the theta2 distribution from the OFF1 coordinate
        hist_off, _ = np.histogram(df_events["theta2_off1"], bins=theta2_bins)

        plt.errorbar(
            x=theta2_bins_center,
            y=hist_off,
            xerr=theta2_bins_width,
            yerr=np.sqrt(hist_off),
            fmt="o",
            markersize=1,
            label=f"OFF1",
        )

        plt.legend(loc="upper right")
