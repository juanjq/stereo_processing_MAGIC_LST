# %%
# packages
import numpy             as np 
import matplotlib.pyplot as plt
import pandas            as pd
import yaml, os, logging, sys, glob
pd.set_option("display.max_columns", None)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from magicctapipe.scripts.lst1_magic import lst1_magic_create_irf, lst1_magic_dl2_to_dl3
from magicctapipe.scripts import create_dl3_index_files

# --- logging --- #
import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# location of the scripts
sys.path.insert(0, '/fefs/aswg/workspace/juan.jimenez/stereo_analysis/scripts')
import auxiliar as aux
aux.params() # graphic parameters

########################################################
# source name
source_name = 'Mrk421'

# configuration file path
config_file   = f'/fefs/aswg/workspace/juan.jimenez/stereo_analysis/config_files/config{source_name}.yaml'
main_dir_irfs = f'/fefs/aswg/workspace/juan.jimenez/data/dl2/irfs'
dir_dl3       = f'/fefs/aswg/workspace/juan.jimenez/data/dl3_BLLac'

compute_irf = True
compute_dl3 = False
########################################################
# Out:
# <style>.container { width:100% !important; }</style>

# %%
dir_irfs = os.path.join(main_dir_irfs, f'irfs_{source_name}') 

with open(config_file, 'rb') as f:
    config = yaml.safe_load(f) 

    
# selecting the MC folder
if source_name == 'Crab':
    path_mcs = '/fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB1.5/GammaTest/v01.2/dec_2276/*.h5' # for CrabNebula
elif source_name == 'BLLac':
    path_mcs = '/fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_3476/*.h5' # for BLLac
elif source_name == 'Mrk421':
    path_mcs = '/fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/*.h5' # for Mrk421
else:
    logger.error(f'The source introduced {source_name} have not specified RFs or is bad written.')
    
logger.info(f'Study of the source: {source_name}')
logger.info(f'\nAll data taken from the path: {path_mcs}')
# Out:
# Study of the source: Mrk421
#
# All data taken from the path: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/*.h5

# %% [markdown]
# # IRF

# %%
if compute_irf:
    # if you want to create it
    aux.createdir(dir_irfs)

    # extracting the MC data
    input_files_gamma = glob.glob(path_mcs)
    input_files_gamma.sort()
    logger.info(f'Found {len(input_files_gamma)} gamma MC files\n')

    for gamma_file in input_files_gamma:
        logger.info(f'\nComputing irf of {gamma_file}')
        lst1_magic_create_irf.create_irf(gamma_file, input_file_proton=None, input_file_electron=None, output_dir=dir_irfs, config=config)
        
        # reset the configuration reading
        with open(config_file, 'rb') as f:
            config = yaml.safe_load(f) 

    
logger.info(f'\n\nFinally the IRF folder will be {dir_irfs}')
# Out:
# Found 67 gamma MC files
#
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_10.0deg_az_102.2deg_LST-1_MAGIC_run102_to_40002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_10.0deg_az_102.2deg_LST-1_MAGIC_run102_to_40002.h5
#
# In total 321487 stereo events are found:
#     M1_M2 (type 0): 7020 events (2.2%)
#     LST1_M1 (type 1): 38936 events (12.1%)
#     LST1_M2 (type 2): 93088 events (29.0%)
#     LST1_M1_M2 (type 3): 182443 events (56.7%)
#
# Extracting the events of the 'software' type...
# --> 198068 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ... 0.16676632597915597
#  0.06309573444801933                  0.1 ... 0.30836026925627436
#                  0.1  0.15848931924611143 ...  0.5184099647209603
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.39507025960539804
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_10.0deg_az_102.199deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_10.0deg_az_248.12deg_LST-1_MAGIC_run101_to_50001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_10.0deg_az_248.12deg_LST-1_MAGIC_run101_to_50001.h5
#
# In total 397728 stereo events are found:
#     M1_M2 (type 0): 10152 events (2.6%)
#     LST1_M1 (type 1): 48523 events (12.2%)
#     LST1_M2 (type 2): 109696 events (27.6%)
#     LST1_M1_M2 (type 3): 229357 events (57.7%)
#
# Extracting the events of the 'software' type...
# --> 249041 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ... 0.05604860134185193
# 0.039810717055349734  0.06309573444801933 ... 0.16795671513956098
#  0.06309573444801933                  0.1 ...  0.3014442482715433
#                  0.1  0.15848931924611143 ...  0.5004976295270085
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.4053352054223949
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_10.0deg_az_248.117deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_14.984deg_az_175.16deg_LST-1_MAGIC_run103_to_50003.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_14.984deg_az_175.16deg_LST-1_MAGIC_run103_to_50003.h5
#
# In total 410358 stereo events are found:
#     M1_M2 (type 0): 10648 events (2.6%)
#     LST1_M1 (type 1): 46118 events (11.2%)
#     LST1_M2 (type 2): 115150 events (28.1%)
#     LST1_M1_M2 (type 3): 238442 events (58.1%)
#
# Extracting the events of the 'software' type...
# --> 259353 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ... 0.05303621510928317
# 0.039810717055349734  0.06309573444801933 ... 0.18839485698641506
#  0.06309573444801933                  0.1 ...   0.360274068202052
#                  0.1  0.15848931924611143 ...  0.5616434215513095
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.4298232198611659
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_14.984deg_az_175.158deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_14.984deg_az_355.16deg_LST-1_MAGIC_run101_to_50001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_14.984deg_az_355.16deg_LST-1_MAGIC_run101_to_50001.h5
#
# In total 364715 stereo events are found:
#     M1_M2 (type 0): 7691 events (2.1%)
#     LST1_M1 (type 1): 45160 events (12.4%)
#     LST1_M2 (type 2): 102438 events (28.1%)
#     LST1_M1_M2 (type 3): 209426 events (57.4%)
# Extracting the events of the 'software' type...
# --> 227213 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ... 0.10872352714766732
# 0.039810717055349734  0.06309573444801933 ... 0.20647682116111732
#  0.06309573444801933                  0.1 ... 0.36373348004982914
#                  0.1  0.15848931924611143 ...  0.5892417394762447
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.4126329027276284
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_14.984deg_az_355.158deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_23.63deg_az_100.76deg_LST-1_MAGIC_run102_to_50002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_23.63deg_az_100.76deg_LST-1_MAGIC_run102_to_50002.h5
#
# In total 447421 stereo events are found:
#     M1_M2 (type 0): 6164 events (1.4%)
#     LST1_M1 (type 1): 54813 events (12.3%)
#     LST1_M2 (type 2): 126866 events (28.4%)
#     LST1_M1_M2 (type 3): 259578 events (58.0%)
#
# Extracting the events of the 'software' type...
# --> 283258 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ... 0.05950793853214075
# 0.039810717055349734  0.06309573444801933 ...  0.1904455174102064
#  0.06309573444801933                  0.1 ...  0.4083235620178383
#                  0.1  0.15848931924611143 ...  0.6299406503133675
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.4215700325968355
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_23.63deg_az_100.758deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_23.63deg_az_259.26deg_LST-1_MAGIC_run101_to_50001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_23.63deg_az_259.26deg_LST-1_MAGIC_run101_to_50001.h5
#
# In total 436762 stereo events are found:
#     M1_M2 (type 0): 7722 events (1.8%)
#     LST1_M1 (type 1): 57454 events (13.2%)
#     LST1_M2 (type 2): 110853 events (25.4%)
#     LST1_M1_M2 (type 3): 260733 events (59.7%)
#
# Extracting the events of the 'software' type...
# --> 285026 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ... 0.14239280002651086
# 0.039810717055349734  0.06309573444801933 ... 0.16527374062561834
#  0.06309573444801933                  0.1 ... 0.37950105342365953
#                  0.1  0.15848931924611143 ...  0.6073448239398159
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.44818909750596336
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_23.63deg_az_259.265deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_102.22deg_LST-1_MAGIC_run105_to_50005.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_102.22deg_LST-1_MAGIC_run105_to_50005.h5
#
# In total 534901 stereo events are found:
#     M1_M2 (type 0): 4485 events (0.8%)
#     LST1_M1 (type 1): 65619 events (12.3%)
#     LST1_M2 (type 2): 147051 events (27.5%)
#     LST1_M1_M2 (type 3): 317746 events (59.4%)
#
# Extracting the events of the 'software' type...
# --> 348503 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ... 0.20042911105751046
#  0.06309573444801933                  0.1 ...  0.4912955140234918
#                  0.1  0.15848931924611143 ...  0.7056264941383786
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.44451302076572236
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_102.217deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_136.05deg_LST-1_MAGIC_run104_to_50004.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_136.05deg_LST-1_MAGIC_run104_to_50004.h5
#
# In total 564358 stereo events are found:
#     M1_M2 (type 0): 7699 events (1.4%)
#     LST1_M1 (type 1): 60482 events (10.7%)
#     LST1_M2 (type 2): 155614 events (27.6%)
#     LST1_M1_M2 (type 3): 340563 events (60.3%)
#
# Extracting the events of the 'software' type...
# --> 372743 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ... 0.21771870287405648
#  0.06309573444801933                  0.1 ...  0.5141359158275917
#                  0.1  0.15848931924611143 ...  0.7214835053105986
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.46646331162531274
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_136.053deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_175.16deg_LST-1_MAGIC_run105_to_50005.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_175.16deg_LST-1_MAGIC_run105_to_50005.h5
#
# In total 583967 stereo events are found:
#     M1_M2 (type 0): 13212 events (2.3%)
#     LST1_M1 (type 1): 59566 events (10.2%)
#     LST1_M2 (type 2): 146527 events (25.1%)
#     LST1_M1_M2 (type 3): 364662 events (62.4%)
#
# Extracting the events of the 'software' type...
# --> 398127 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ...  0.2587821047093835
#  0.06309573444801933                  0.1 ...  0.5262810036942539
#                  0.1  0.15848931924611143 ...  0.7300054882709216
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.49060575316825544
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_175.158deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_214.26deg_LST-1_MAGIC_run103_to_50003.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_214.26deg_LST-1_MAGIC_run103_to_50003.h5
#
# In total 543103 stereo events are found:
#     M1_M2 (type 0): 12344 events (2.3%)
#     LST1_M1 (type 1): 61252 events (11.3%)
#     LST1_M2 (type 2): 119326 events (22.0%)
#     LST1_M1_M2 (type 3): 350181 events (64.5%)
#
# Extracting the events of the 'software' type...
# --> 381643 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ... 0.22928055785224832
#  0.06309573444801933                  0.1 ...  0.5017825533672845
#                  0.1  0.15848931924611143 ...  0.7092010640814044
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.46775766084383047
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_214.263deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_248.1deg_LST-1_MAGIC_run104_to_50004.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_248.1deg_LST-1_MAGIC_run104_to_50004.h5
# In total 522292 stereo events are found:
#     M1_M2 (type 0): 7373 events (1.4%)
#     LST1_M1 (type 1): 67717 events (13.0%)
#     LST1_M2 (type 2): 117902 events (22.6%)
#     LST1_M1_M2 (type 3): 329300 events (63.0%)
#
# Extracting the events of the 'software' type...
# --> 360448 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ... 0.21757073682763145
#  0.06309573444801933                  0.1 ... 0.47638361884488256
#                  0.1  0.15848931924611143 ...  0.6889406088824386
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ... 0.46587574047827124
#   63.095734448019364                100.0 ...                0.05
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_248.099deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_355.16deg_LST-1_MAGIC_run102_to_50002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_32.059deg_az_355.16deg_LST-1_MAGIC_run102_to_50002.h5
#
# In total 455411 stereo events are found:
#     M1_M2 (type 0): 5878 events (1.3%)
#     LST1_M1 (type 1): 52991 events (11.6%)
#     LST1_M2 (type 2): 112690 events (24.7%)
#     LST1_M1_M2 (type 3): 283852 events (62.3%)
#
# Extracting the events of the 'software' type...
# --> 308633 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ... 0.2532025253513991
#  0.06309573444801933                  0.1 ... 0.5178627028680112
#                  0.1  0.15848931924611143 ... 0.7240476217849182
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.5000852176648035
#   63.095734448019364                100.0 ...               0.05
#                100.0   158.48931924611142 ...               0.05
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_32.059deg_az_355.158deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_35.904deg_az_17.46deg_LST-1_MAGIC_run102_to_50002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_35.904deg_az_17.46deg_LST-1_MAGIC_run102_to_50002.h5
#
# In total 421780 stereo events are found:
#     M1_M2 (type 0): 4590 events (1.1%)
#     LST1_M1 (type 1): 47872 events (11.3%)
#     LST1_M2 (type 2): 94208 events (22.3%)
#     LST1_M1_M2 (type 3): 275110 events (65.2%)
#
# Extracting the events of the 'software' type...
# --> 298453 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...  0.209344771466772
#  0.06309573444801933                  0.1 ... 0.5496939090132478
#                  0.1  0.15848931924611143 ... 0.7356888335933849
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.4755396936199049
#   63.095734448019364                100.0 ...               0.05
#                100.0   158.48931924611142 ...               0.05
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_35.904deg_az_17.462deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_35.904deg_az_342.54deg_LST-1_MAGIC_run101_to_50001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_35.904deg_az_342.54deg_LST-1_MAGIC_run101_to_50001.h5
#
# In total 424708 stereo events are found:
#     M1_M2 (type 0): 3924 events (0.9%)
#     LST1_M1 (type 1): 49628 events (11.7%)
#     LST1_M2 (type 2): 105118 events (24.8%)
#     LST1_M1_M2 (type 3): 266038 events (62.6%)
#
# Extracting the events of the 'software' type...
# --> 289483 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ... 0.2667027154499152
#  0.06309573444801933                  0.1 ... 0.5265506753851277
#                  0.1  0.15848931924611143 ...  0.723295687746559
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.5054362168795041
#   63.095734448019364                100.0 ...               0.05
#                100.0   158.48931924611142 ...               0.05
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_35.904deg_az_342.538deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_39.646deg_az_24.33deg_LST-1_MAGIC_run104_to_50004.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_39.646deg_az_24.33deg_LST-1_MAGIC_run104_to_50004.h5
#
# In total 472753 stereo events are found:
#     M1_M2 (type 0): 4180 events (0.9%)
#     LST1_M1 (type 1): 53318 events (11.3%)
#     LST1_M2 (type 2): 99561 events (21.1%)
#     LST1_M1_M2 (type 3): 315694 events (66.8%)
#
# Extracting the events of the 'software' type...
# --> 343341 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ...                0.05
#  0.06309573444801933                  0.1 ...  0.5618350415599279
#                  0.1  0.15848931924611143 ...   0.675753183349266
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.5062593936246726
#   63.095734448019364                100.0 ... 0.38570115393956717
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_39.646deg_az_24.333deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_39.646deg_az_335.67deg_LST-1_MAGIC_run103_to_50003.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_39.646deg_az_335.67deg_LST-1_MAGIC_run103_to_50003.h5
#
# In total 478412 stereo events are found:
#     M1_M2 (type 0): 3391 events (0.7%)
#     LST1_M1 (type 1): 55826 events (11.7%)
#     LST1_M2 (type 2): 117383 events (24.5%)
#     LST1_M1_M2 (type 3): 301812 events (63.1%)
#
# Extracting the events of the 'software' type...
# --> 329882 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ... 0.5369752829973574
#                  0.1  0.15848931924611143 ...  0.658620764897233
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.5179483656622768
#   63.095734448019364                100.0 ... 0.4131923634042047
#                100.0   158.48931924611142 ...               0.05
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_39.646deg_az_335.667deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_120.31deg_LST-1_MAGIC_run207_to_50007.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_120.31deg_LST-1_MAGIC_run207_to_50007.h5
#
# In total 568047 stereo events are found:
#     M1_M2 (type 0): 2467 events (0.4%)
#     LST1_M1 (type 1): 64293 events (11.3%)
#     LST1_M2 (type 2): 149529 events (26.3%)
#     LST1_M1_M2 (type 3): 351758 events (61.9%)
#
# Extracting the events of the 'software' type...
# --> 389145 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ...                0.05
#  0.06309573444801933                  0.1 ...   0.546503267683975
#                  0.1  0.15848931924611143 ...   0.739733717822295
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.5519111681655283
#   63.095734448019364                100.0 ... 0.42383584893368376
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_43.197deg_az_120.311deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_143.44deg_LST-1_MAGIC_run109_to_50009.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_143.44deg_LST-1_MAGIC_run109_to_50009.h5
#
# In total 612664 stereo events are found:
#     M1_M2 (type 0): 4921 events (0.8%)
#     LST1_M1 (type 1): 62134 events (10.1%)
#     LST1_M2 (type 2): 156598 events (25.6%)
#     LST1_M1_M2 (type 3): 389011 events (63.5%)
#
# Extracting the events of the 'software' type...
# --> 428957 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ... 0.5692955378716847
#                  0.1  0.15848931924611143 ... 0.7559931720589621
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.5461915196972373
#   63.095734448019364                100.0 ... 0.4238381309570647
#                100.0   158.48931924611142 ...               0.05
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_43.197deg_az_143.441deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_175.16deg_LST-1_MAGIC_run1010_to_500010.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_43.197deg_az_175.16deg_LST-1_MAGIC_run1010_to_500010.h5
#
# In total 654274 stereo events are found:
#     M1_M2 (type 0): 10344 events (1.6%)
#     LST1_M1 (type 1): 61059 events (9.3%)
#     LST1_M2 (type 2): 148133 events (22.6%)
#     LST1_M1_M2 (type 3): 434738 events (66.4%)
#
# Extracting the events of the 'software' type...
# --> 477601 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...         cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... -------------------
#                 0.01 0.015848931924611134 ...                0.05
# 0.015848931924611134 0.025118864315095794 ...                0.05
# 0.025118864315095794 0.039810717055349734 ...                0.05
# 0.039810717055349734  0.06309573444801933 ...                0.05
#  0.06309573444801933                  0.1 ...   0.582481816228561
#                  0.1  0.15848931924611143 ...  0.7641197148328753
#                  ...                  ... ...                 ...
#   39.810717055349734   63.095734448019364 ...  0.5721458984317157
#   63.095734448019364                100.0 ... 0.44373427849555874
#                100.0   158.48931924611142 ...                0.05
#   158.48931924611142   251.18864315095823 ...                0.05
#   251.18864315095823    398.1071705534977 ...                0.05
#    398.1071705534977    630.9573444801943 ...                0.05
#    630.9573444801943               1000.0 ...                0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_43.197deg_az_175.158deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# ...
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ...               0.85
#   63.095734448019364                100.0 ... 0.8319588334870334
#                100.0   158.48931924611142 ...  0.823469425180989
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_70.732deg_az_29.341deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_70.732deg_az_330.66deg_LST-1_MAGIC_run102_to_100002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_70.732deg_az_330.66deg_LST-1_MAGIC_run102_to_100002.h5
#
# In total 412531 stereo events are found:
#     M1_M2 (type 0): 79 events (0.0%)
#     LST1_M1 (type 1): 25938 events (6.3%)
#     LST1_M2 (type 2): 62008 events (15.0%)
#     LST1_M1_M2 (type 3): 324506 events (78.7%)
#
# Extracting the events of the 'software' type...
# --> 360210 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ...               0.85
#   63.095734448019364                100.0 ... 0.8392019886863916
#                100.0   158.48931924611142 ... 0.8365822241220037
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_70.732deg_az_330.659deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_73.142deg_az_28.02deg_LST-1_MAGIC_run101_to_200001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_73.142deg_az_28.02deg_LST-1_MAGIC_run101_to_200001.h5
#
# In total 287848 stereo events are found:
#     M1_M2 (type 0): 71 events (0.0%)
#     LST1_M1 (type 1): 10736 events (3.7%)
#     LST1_M2 (type 2): 28015 events (9.7%)
#     LST1_M1_M2 (type 3): 249026 events (86.5%)
#
# Extracting the events of the 'software' type...
# --> 268589 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.8318345177648439
#   63.095734448019364                100.0 ... 0.8099613845957641
#                100.0   158.48931924611142 ... 0.8002952027851696
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_73.142deg_az_28.021deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_73.142deg_az_331.98deg_LST-1_MAGIC_run102_to_200002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_73.142deg_az_331.98deg_LST-1_MAGIC_run102_to_200002.h5
#
# In total 326860 stereo events are found:
#     M1_M2 (type 0): 60 events (0.0%)
#     LST1_M1 (type 1): 18009 events (5.5%)
#     LST1_M2 (type 2): 44186 events (13.5%)
#     LST1_M1_M2 (type 3): 264605 events (81.0%)
#
# Extracting the events of the 'software' type...
# --> 292684 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.8488636115668621
#   63.095734448019364                100.0 ... 0.8205339386854287
#                100.0   158.48931924611142 ... 0.8193175550058504
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_73.142deg_az_331.979deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.226deg_az_318.97deg_LST-1_MAGIC_run101_to_200001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.226deg_az_318.97deg_LST-1_MAGIC_run101_to_200001.h5
#
# In total 169093 stereo events are found:
#     M1_M2 (type 0): 35 events (0.0%)
#     LST1_M1 (type 1): 9332 events (5.5%)
#     LST1_M2 (type 2): 17575 events (10.4%)
#     LST1_M1_M2 (type 3): 142151 events (84.1%)
#
# Extracting the events of the 'software' type...
# --> 155312 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.8106783868145294
#   63.095734448019364                100.0 ... 0.7911072605542641
#                100.0   158.48931924611142 ... 0.7919807714730807
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_75.226deg_az_318.974deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.522deg_az_26.46deg_LST-1_MAGIC_run101_to_200001.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.522deg_az_26.46deg_LST-1_MAGIC_run101_to_200001.h5
#
# In total 168695 stereo events are found:
#     M1_M2 (type 0): 44 events (0.0%)
#     LST1_M1 (type 1): 5541 events (3.3%)
#     LST1_M2 (type 2): 13933 events (8.3%)
#     LST1_M1_M2 (type 3): 149177 events (88.4%)
#
# Extracting the events of the 'software' type...
# --> 159610 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ...  0.808204172570625
#   63.095734448019364                100.0 ... 0.7792266195992192
#                100.0   158.48931924611142 ... 0.7586229461353164
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_75.522deg_az_26.462deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
# Computing irf of /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.522deg_az_333.54deg_LST-1_MAGIC_run102_to_200002.h5
#
# Quality cuts: disp_diff_mean < 0.22
# Event type: software
# DL2 weight type: variance
#
# Input gamma MC DL2 data file: /fefs/aswg/LST1MAGIC/mc/DL2/ST0316A/NSB0.5/GammaTest/v01.2/dec_4822/dl2_gamma_zd_75.522deg_az_333.54deg_LST-1_MAGIC_run102_to_200002.h5
#
# In total 220050 stereo events are found:
#     M1_M2 (type 0): 39 events (0.0%)
#     LST1_M1 (type 1): 10894 events (5.0%)
#     LST1_M2 (type 2): 25518 events (11.6%)
#     LST1_M1_M2 (type 3): 183599 events (83.4%)
#
# Extracting the events of the 'software' type...
# --> 201649 stereo events
#
# Is diffuse MC: False
#
# Mean true FoV offset: 0.4 deg
# --> FoV offset bin: [0.3 0.5] deg
#
# IRF type: POINT-LIKE
#
# Is proton MC: False
# Is electron MC: False
#
# Energy bins (log space):
#     start: 0.01 TeV
#     stop: 1000 TeV
#     n_edges: 26
#
# Migration bins (log space):
#     start: 0.2
#     stop: 5
#     n_edges: 31
#
# Dynamic gammaness cuts:
#     efficiency: 0.9
#     min_cut: 0.05
#     max_cut: 0.85
#
# Gammaness-cut table:
#
#         low                  high         ...        cut
#         TeV                  TeV          ...
# -------------------- -------------------- ... ------------------
#                 0.01 0.015848931924611134 ...               0.05
# 0.015848931924611134 0.025118864315095794 ...               0.05
# 0.025118864315095794 0.039810717055349734 ...               0.05
# 0.039810717055349734  0.06309573444801933 ...               0.05
#  0.06309573444801933                  0.1 ...               0.05
#                  0.1  0.15848931924611143 ...               0.05
#                  ...                  ... ...                ...
#   39.810717055349734   63.095734448019364 ... 0.8140819327956565
#   63.095734448019364                100.0 ... 0.7854135284721435
#                100.0   158.48931924611142 ... 0.7913623692908037
#   158.48931924611142   251.18864315095823 ...               0.05
#   251.18864315095823    398.1071705534977 ...               0.05
#    398.1071705534977    630.9573444801943 ...               0.05
#    630.9573444801943               1000.0 ...               0.05
# Length = 25 rows
#
# Creating a gammaness-cut HDU...
#
# Global theta cut: 0.2 deg
#
# Creating an effective-area HDU...
# Creating an energy-dispersion HDU...
#
# Output file: /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421/irf_zd_75.522deg_az_333.538deg_software_gh_dyn0.9_theta_glob0.2deg.fits.gz
#
#
# Finally the IRF folder will be /fefs/aswg/workspace/juan.jimenez/data/dl2/irfs/irfs_Mrk421

# %% [markdown]
# ## DL2 to DL3

# %%
aux.createdir(dir_dl3)

dir_dl2 = f'/fefs/aswg/workspace/juan.jimenez/data/dl2/stereo_raw_dl2_{source_name}/*'
files_dl2 = glob.glob(dir_dl2)
files_dl2.sort()

runs_dl2 = sorted([int(f.split('/')[-1].split('.')[1].replace('Run', '')) for f in files_dl2])

logger.info(f'\nThe DL2 directory ---> {dir_dl2}\nWhere {len(files_dl2)} files are found')
logger.info(f'\nThe IRF directory --> {dir_irfs}')
logger.info(f'\nThe DL3 directory --> {dir_dl3}')

if compute_dl3 == True:
    for file, run in zip(files_dl2, runs_dl2):

        logger.info(f'\nComputing irf of {file}')
        lst1_magic_dl2_to_dl3.dl2_to_dl3(input_file_dl2=file, input_dir_irf=dir_irfs, output_dir=dir_dl3, config=config)

        # reset the configuration reading
        with open(config_file, 'rb') as f:
            config = yaml.safe_load(f) 
            
# We need to create index files
create_dl3_index_files(dir_dl3)
